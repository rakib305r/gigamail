# %%
# ---read csv or excel file---
import pandas as pd 
df = pd.read_csv("spi.csv")

# %%
print(df)
# Out:
#     Unnamed: 0   ID    Name  Roll     Post     Hobby  Marks Result
# 0            0  101   Rakib    56  STUDENT  Football     85   pass
# 1            1  102  Rayhan    45  STUDENT   Cricket     42   fail
# 2            2  103  Shimul    13  STUDENT  Football     67   fail
# 3            3  104   Rakib    22  STUDENT   Cricket     91   pass
# 4            4  105   Hasan    34  STUDENT  Football     53   fail
# 5            5  106  Tanvir    17  STUDENT   Cricket     78   fail
# 6            6  107   Rakib    28  STUDENT  Football     49   fail
# 7            7  108    Arif    39  STUDENT   Cricket     95   pass
# 8            8  109  Rayhan    11  STUDENT  Football     62   fail
# 9            9  110  Mehedi    52  STUDENT   Cricket     88   pass
# 10          10  111    Siam    26  STUDENT  Football     74   fail
# 11          11  112   Rohan    31  STUDENT   Cricket     59   fail
# 12          12  113   Jahid    44  STUDENT  Football     41   fail
# ...

# %%
df.head() #first 5 row show with markable

# %%
df.tail() #last 5 row show with markable

# %%
df.info() #data type information

# %%
df.describe() #describe about data

# %%
df.columns #show all columns name and columns data_type

# %%
df.index #index range like start,stop,step

# %%
len(df["Name"]) #df and columns name show only all columns & len defined how many data in columns
# Out:
# 15

# %%
df[["Name","Roll"]] # 2 columns so 2 brackets

# %%
df.iloc[3] # 3 no. all index show

# %%
df.iloc[3]["Roll"] # specific index show
# Out:
# np.int64(22)

# %%
df[df["Post"] == "STUDENT"] # FIND same category in the columns but show all rows in the specific columns

# %%
df[(df["Name"] == "Rakib") & (df["Hobby"] == "Football")] #more specific

# %%
df[(df["Name"] == "Rakib") | (df["Post"] == "STUDENT")] # any one specific

# %%
df[df["Marks"] > 90] #Data Filtering

# %%
df[df["Name"].str.startswith('R')] #String Matching Filter

# %%
df[df["Name"].isin(["Rakib","Rayhan"])] # multiple String Matching Filter

# %%
df[~df["Name"].isin(["Rakib","Rayhan"])] # "~" it's mean revers, it's work every where

# %%
df.to_csv("spi.csv") # project save

# %%
df.sort_values(by="Roll", ascending=True) # sorting by small to big

# %%
df.assign(Result = df["Marks"].apply(lambda x: "pass" if x > 80 else "fail")) # new columns add and pass or fail typing on column

# %%
df.shape # how many columns and row
