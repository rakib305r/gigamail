# %%
student = {
    'Rakib':{
        'name': 'rakib',
        'roll': 871203,
        'dept': 'CST'
    },
    'Tutul':{
        'name': 'tutul',
        'roll': 871200,
        'dept': 'ET'
    },'Jimu':{
        'name': 'jimu',
        'roll': 871210,
        'dept': 'CT'
    },
    'year': 2026
}
print(student['Rakib'])  # rakib details call

# %%
print(student["Rakib"]["roll"]) # specifically call

# %%
student.get('Rakib') # get method

# %%
student.keys() # key method

# %%
student.values() # value method

# %%
student['year'] = 2017 # value change
print(student)

# %%
student.update({'Rakib': 'Rakib is a topper'}) # update value
print(student)

# %%
student.pop("Tutul") # any item remove
print(student)

# %%
student.popitem() # last item remove
print(student)
